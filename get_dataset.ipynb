# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 32.05 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip3 install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 5.5 MB/s
# ...
#      |████████████████████████████████| 547 kB 47.0 MB/s
# ...
#      |████████████████████████████████| 79 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 8.5 MB 35.5 MB/s
# ...
#      |████████████████████████████████| 138 kB 55.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader --classes Apple Orange Tomato --type_csv train
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Apple.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 42258 KB/s, 0 seconds passed
# ...

# %%
# !python3 /content/OIDv4_ToolKit/main.py downloader --classes Apple Orange Tomato --type_csv validation
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Apple.
#    [ERROR] | Missing the validation-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 16 MB, 43061 KB/s, 0 seconds passed
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Fruit --type_csv test
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Fruit.
#    [ERROR] | Missing the test-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 49 MB, 50933 KB/s, 1 seconds passed
# ...

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
img = load_img('/content/OID/Dataset/train/Fruit/0fd56b2e276fdfb8.jpg')
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
# !python3 /content/OIDv4_ToolKit/main.py visualizer
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#             _    _ _                  _ _
#            | |  | (_)                | (_)
#            | |  | |_  ___ _   _  ____| |_ _____ ____  ____
#             \ \/ /| |/___) | | |/ _  | | (___  ) _  )/ ___)
#              \  / | |___ | |_| ( ( | | | |/ __( (/ /| |
#               \/  |_(___/ \____|\_||_|_|_(_____)____)_|
#
#
# Which folder do you want to visualize (train, test, validation)? <exit>
# > train
# Which class? <exit>
# Traceback (most recent call last):
#   File "/content/OIDv4_ToolKit/main.py", line 37, in <module>
#     bounding_boxes_images(args, DEFAULT_OID_DIR)
#   File "/content/OIDv4_ToolKit/modules/bounding_boxes.py", line 162, in bounding_boxes_images
# ...

# %%
import os

print(len(os.listdir('/content/drive/MyDrive/OID/Dataset/validation/Fruit')))
# Out:
# 417
